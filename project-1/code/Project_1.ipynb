# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Data Analysis of Singapore Rainfall

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# According to the [Meteorological Services Singapore](http://www.weather.gov.sg/climate-climate-of-singapore/#:~:text=Singapore%20is%20situated%20near%20the,month%2Dto%2Dmonth%20variation.), Singapore has typical tropical climate with adundant rainfall, high and uniform temperatures and high humidity all year round, since its situated near the equator. There are many factors that help us understand the climate of a country and in this project we are going to look into a few, especially rainfall.
#
# Singapore’s climate is characterised by two main monsoon seasons separated by inter-monsoonal periods.  The **Northeast Monsoon** occurs from December to early March, and the **Southwest Monsoon** from June to September.
#
# The major weather systems affecting Singapore that can lead to heavy rainfall are:
#
# -Monsoon surges, or strong wind episodes in the Northeast Monsoon flow bringing about major rainfall events;
#
# -Sumatra squalls, an organised line of thunderstorms travelling eastward across Singapore, having developed over the island of Sumatra or Straits of Malacca west of us;
#
# -Afternoon and evening thunderstorms caused by strong surface heating and by the sea breeze circulation that develops in the afternoon.
#
# Singapore’s climate station has been located at several different sites in the past 140 years. The station had been decommissioned at various points in the past due to changes to local land use in the site’s vicinity, and had to be relocated. Since 1984, the climate station has been located at **Changi**.
#
# There are other metrics of climate such as temperature, humidity, sun shine duration, wind speed, cloud cover etc. All the dataset used in the project comes from [data.gov.sg](data.gov.sg), as recorded at the Changi climate station

# %% [markdown]
# ### Selected Datasets
#
# - [Monthly Number of Rainy Days](https://data.gov.sg/dataset/rainfall-monthly-number-of-rain-days): Monthly number of rain days from 1982 to 2022. A day is considered to have “rained” if the total rainfall for that day is 0.2mm or more.
#
# - [Monthly Total Rainfall](https://data.gov.sg/dataset/rainfall-monthly-total): Monthly total rain recorded in mm(millimeters) from 1982 to 2022
#
# - [Surface Air Temperature](https://data.gov.sg/dataset/surface-air-temperature-mean-daily-minimum): Monthly mean surface air temperature in celsius from 1982 to 2022
#
# - [Monthly Mean Sunshine Duration](https://data.gov.sg/dataset/sunshine-duration-monthly-mean-daily-duration): Monthly mean sunshine hours from 1982 to 2022
#
# - [Relative Humidity](https://data.gov.sg/dataset/relative-humidity-monthly-mean): Monthly mean relative humidity from 1982 to 2022
#
# - [Monthly Maximum Daily Rainfall](https://data.gov.sg/dataset/rainfall-monthly-maximum-daily-total): Monthly maximum rainfall in a day from 1982 to 2022
#
# - [Hourly wet bulb temperature](https://data.gov.sg/dataset/wet-bulb-temperature-hourly): Hourly wet bulb temperature from 1982 to 2022
#
# - [Singapore Seafood Supply](https://tablebuilder.singstat.gov.sg/table/TS/M890741#!): Singapore's seafood supply from 1999 to 2022

# %% [markdown]
# ### Data Sources:

# %% [markdown]
# 1. https://data.gov.sg
# 2. https://tablebuilder.singstat.gov.sg

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# - In the past years, Singapore has encountered a growing number of flash floods due to unpredictable weather conditions, including heavy rainfall caused by climate change and global warming. These floods can significantly affect daily business operations and threaten the stability of Singapore's food supply. As a Data Analyst employed by the Singapore Food Agency, we would like to incorporate the use of weather analytics to examine how the rainfall parameters concerning Singapore's weather can impact the overall seafood supply and demand in the local market.The analysis results will provide valuable insights to various audiences and stakeholders in Singapore such as restaurants, F&B retailers and grocery suppliers relying on the local seafood market for their sales and operations, as well as to assist them in better optimising their seafood resources during the rainy seasons.

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Since the recent decades, climate change has resulted in a rapid overall increase in the average temperature of our planet. This has resulted severe consequences such as the melting of polar ice caps which caused the rise in global sea levels, and also being subjected to extreme weather conditions. As a result, communities and nations along the coastlines are becoming increasingly vulnerable to floods and threats such as tsunamis.
#
# Out of all the regions in the world, countries in Asia and Southeast Asia have been assessed to have the highest risk towards the impacts of sea level rise and extreme weather conditions on the local population, with 12 out of 20 countries having the greatest exposure to sea level rise being found in Asia(IPCC Sixth Assessment Report 2022: Chapter 10: Asia. In Climate Change 2022: Impacts, Adaptation and Vulnerability).
#
# Singapore is a small tropical island nation surrounded by coastlines in all directions with high amounts of annual rainfall. It is therefore a prime candidate in being exposed to these extreme weather conditions and threats resulting from rising sea levels, which can result in disruptions to business supply chains as well as volatile food pricings due to its reliance on imported food supply which accounts for up to 90%(A sustainable food system for Singapore and beyond, SFA Singapore).

# %% [markdown]
# 1. IPCC Sixth Assessment Report 2022: Chapter 10: Asia. In Climate Change 2022: Impacts, Adaptation and Vulnerability
#
#
# 2. Singapore Food Statistics 2021:
# https://www.sfa.gov.sg/docs/default-source/publication/sg-food-statistics/singapore-food-statistics-2021.pdf
#
#
# 3. IN FOCUS: How climate change can threaten food production in Singapore, CNA Singapore, 19 Dec 2020:
# https://www.channelnewsasia.com/singapore/climate-change-singapore-food-production-fish-eggs-1340266
#
# 4. Enhanced phytoplankton bloom triggered by atmospheric high-pressure systems over the Northern Arabian Sea, Prasad G.Thoppil, 14 Jan 2023: https://www.nature.com/articles/s41598-023-27785-z
#
# 5. Climate change effects on aquaculture production, Global Seafood Alliance, 20 Sept 2021: https://www.globalseafood.org/advocate/climate-change-effects-on-aquaculture-production/
#
# 6. Climate of Singapore: http://www.weather.gov.sg/climate-climate-of-singapore/

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def avg(num_list):
    return sum(num_list) / len(num_list)
avg([3,3,5,6,7,8])
# Out:
# 5.333333333333333

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def std_dev(num_list):
    total = 0
    cnt = 0
    for i in num_list:
        total += ((i - avg(num_list))**2)
        cnt += 1
    return (total/cnt)**0.5
std_dev([3,3,5,6,7,8])
# Out:
# 1.8856180831641267

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning of weather dataset
#
# Import all the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary. Make sure to comment your code to showcase the intent behind the data processing step.
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values and datatype.
# 3. Check for any obvious issues with the observations.
# 4. Fix any errors you identified in steps 2-3.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If the month column data is better analyzed as month and year, create new columns for the same
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
#     - Since different climate metrics are in month format, you can merge them into one single dataframe for easier analysis
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
#read monthly rainfall dataset and display first 5 rows
df1 = pd.read_csv('../data/rainfall-monthly-total.csv')
df1.head()
# Out:
#      month  total_rainfall
# 0  1982-01           107.1
# 1  1982-02            27.8
# 2  1982-03           160.8
# 3  1982-04           157.0
# 4  1982-05           102.2

# %%
#read monthly number of rainy days and display first 5 rows
df2 = pd.read_csv('../data/rainfall-monthly-number-of-rain-days.csv')
df2.head()
# Out:
#      month  no_of_rainy_days
# 0  1982-01                10
# 1  1982-02                 5
# 2  1982-03                11
# 3  1982-04                14
# 4  1982-05                10

# %%
#read monthly highest rainfall in a day dataset and display first 5 rows
df3 = pd.read_csv('../data/rainfall-monthly-highest-daily-total.csv')
df3.head()
# Out:
#      month  maximum_rainfall_in_a_day
# 0  1982-01                       36.5
# 1  1982-02                        9.4
# 2  1982-03                       61.7
# 3  1982-04                       45.1
# 4  1982-05                       33.0

# %%
#read monthly relative humidity mean dataset and display first 5 rows
df4 = pd.read_csv('../data/relative-humidity-monthly-mean.csv')
df4.head()
# Out:
#      month  mean_rh
# 0  1982-01     81.2
# 1  1982-02     79.5
# 2  1982-03     82.3
# 3  1982-04     85.9
# 4  1982-05     83.2

# %%
#read monthly sunshine hours dataset and display first 5 rows
df5 = pd.read_csv('../data/sunshine-duration-monthly-mean-daily-duration.csv')
df5.head()
# Out:
#      month  mean_sunshine_hrs
# 0  1982-01                5.6
# 1  1982-02                7.6
# 2  1982-03                5.1
# 3  1982-04                4.7
# 4  1982-05                5.8

# %%
#read monthly surface air temperature dataset and display first 5 rows
df6 = pd.read_csv('../data/surface-air-temperature-monthly-mean.csv')
df6.head()
# Out:
#      month  mean_temp
# 0  1982-01       25.9
# 1  1982-02       27.1
# 2  1982-03       27.2
# 3  1982-04       27.0
# 4  1982-05       28.0

# %%
#read hourly wet bulb temperature dataset and display first 5 rows
df7 = pd.read_csv('../data/wet-bulb-temperature-hourly.csv')
df7.head()
# Out:
#      wbt_date  wbt_time  wet_bulb_temperature
# 0  1982-01-01         1                  24.7
# 1  1982-01-01         2                  24.5
# 2  1982-01-01         3                  24.3
# 3  1982-01-01         4                  24.2
# 4  1982-01-01         5                  24.2

# %%
#check for null values
df7.isnull().sum()
# Out:
# wbt_date                0
# wbt_time                0
# wet_bulb_temperature    0
# dtype: int64

# %%
#split wbt_date into year, month and date columns, then drop wbt_date, date, wbt_time columns
df7[['year', 'month', 'date']] = df7['wbt_date'].str.split('-', expand=True)
df7.drop(['wbt_date', 'date', 'wbt_time'], axis=1, inplace=True)
df7.head()
# Out:
#    wet_bulb_temperature  year month
# 0                  24.7  1982    01
# 1                  24.5  1982    01
# 2                  24.3  1982    01
# 3                  24.2  1982    01
# 4                  24.2  1982    01

# %%
#group by year, month on mean, then reset index
wbt_df = df7.groupby(['year', 'month']).mean()
wbt_df.reset_index(inplace=True)
wbt_df.head()
# Out:
#    year month  wet_bulb_temperature
# 0  1982    01             23.456048
# 1  1982    02             24.297619
# 2  1982    03             24.811559
# 3  1982    04             25.103750
# 4  1982    05             25.689651

# %%
#merge all 6 weather datasets together on month with left join, then split month column into year and month
merged_df = df6.merge(df5, on='month', how='left')
merged_df = merged_df.merge(df4, on='month', how='left')
merged_df = merged_df.merge(df3, on='month', how='left')
merged_df = merged_df.merge(df2, on='month', how='left')
merged_df = merged_df.merge(df1, on='month', how='left')
merged_df[['year', 'month']] = merged_df['month'].str.split('-', expand=True)
merged_df.head()
# Out:
#   month  mean_temp  mean_sunshine_hrs  mean_rh  maximum_rainfall_in_a_day  \
# 0    01       25.9                5.6     81.2                       36.5
# 1    02       27.1                7.6     79.5                        9.4
# 2    03       27.2                5.1     82.3                       61.7
# 3    04       27.0                4.7     85.9                       45.1
# 4    05       28.0                5.8     83.2                       33.0
#
#    no_of_rainy_days  total_rainfall  year
# 0              10.0           107.1  1982
# 1               5.0            27.8  1982
# 2              11.0           160.8  1982
# 3              14.0           157.0  1982
# 4              10.0           102.2  1982

# %%
#final merge with wet bulb data set on yeaer and month columns with left join
climate = merged_df.merge(wbt_df, on=['year', 'month'], how='left')
climate.head()
# Out:
#   month  mean_temp  mean_sunshine_hrs  mean_rh  maximum_rainfall_in_a_day  \
# 0    01       25.9                5.6     81.2                       36.5
# 1    02       27.1                7.6     79.5                        9.4
# 2    03       27.2                5.1     82.3                       61.7
# 3    04       27.0                4.7     85.9                       45.1
# 4    05       28.0                5.8     83.2                       33.0
#
#    no_of_rainy_days  total_rainfall  year  wet_bulb_temperature
# 0              10.0           107.1  1982             23.456048
# 1               5.0            27.8  1982             24.297619
# 2              11.0           160.8  1982             24.811559
# 3              14.0           157.0  1982             25.103750
# 4              10.0           102.2  1982             25.689651

# %%
#dataframe info
climate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 0 to 490
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   month                      491 non-null    object
#  1   mean_temp                  491 non-null    float64
#  2   mean_sunshine_hrs          491 non-null    float64
#  3   mean_rh                    491 non-null    float64
#  4   maximum_rainfall_in_a_day  491 non-null    float64
#  5   no_of_rainy_days           488 non-null    float64
#  6   total_rainfall             488 non-null    float64
#  7   year                       491 non-null    object
#  8   wet_bulb_temperature       491 non-null    float64
# dtypes: float64(7), object(2)
# memory usage: 38.4+ KB

# %%
#summary statistics
climate.describe().T
# Out:
#                            count        mean         std        min  \
# mean_temp                  491.0   27.678615    0.799905  25.400000
# mean_sunshine_hrs          491.0    5.676171    1.212024   2.700000
# mean_rh                    491.0   82.224644    3.417366  72.000000
# maximum_rainfall_in_a_day  491.0   52.277189   35.647758   0.200000
# no_of_rainy_days           488.0   14.061475    4.947394   1.000000
# total_rainfall             488.0  177.163730  113.916029   0.200000
# wet_bulb_temperature       491.0   25.254985    0.593604  23.391129
#
#                                  25%         50%         75%         max
# mean_temp                  27.100000   27.700000   28.300000   29.500000
# mean_sunshine_hrs           4.800000    5.600000    6.450000    9.300000
# mean_rh                    79.900000   82.600000   84.650000   90.700000
# maximum_rainfall_in_a_day  30.800000   43.800000   62.850000  216.200000
# ...

# %%
#check for null values
climate.isnull().sum()
# Out:
# month                        0
# mean_temp                    0
# mean_sunshine_hrs            0
# mean_rh                      0
# maximum_rainfall_in_a_day    0
# no_of_rainy_days             3
# total_rainfall               3
# year                         0
# wet_bulb_temperature         0
# dtype: int64

# %%
#map the month values to strings
climate['month'] = climate['month'].map({'01': 'Jan', '02': 'Feb', '03': 'Mar', '04': 'Apr', '05': 'May', 
                                               '06': 'Jun', '07': 'Jul', '08': 'Aug', '09': 'Sep', '10': 'Oct', 
                                               '11': 'Nov', '12': 'Dec'})
climate.head()
# Out:
#   month  mean_temp  mean_sunshine_hrs  mean_rh  maximum_rainfall_in_a_day  \
# 0   Jan       25.9                5.6     81.2                       36.5
# 1   Feb       27.1                7.6     79.5                        9.4
# 2   Mar       27.2                5.1     82.3                       61.7
# 3   Apr       27.0                4.7     85.9                       45.1
# 4   May       28.0                5.8     83.2                       33.0
#
#    no_of_rainy_days  total_rainfall  year  wet_bulb_temperature
# 0              10.0           107.1  1982             23.456048
# 1               5.0            27.8  1982             24.297619
# 2              11.0           160.8  1982             24.811559
# 3              14.0           157.0  1982             25.103750
# 4              10.0           102.2  1982             25.689651

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |total_rainfall|float|rainfall-monthly-total|Total rainfall in mm|
# |no_of_rainy_days|float|rainfall-monthly-number-of-rain-days| Number of Rainy days|
# |maximum_rainfall_in_a_day|float|rainfall-monthly-highest-daily-total|Maximum rainfall in a day|
# |mean_air_temp|float|surface-air-temperature-monthly-mean|Monthly mean surface air temperature|
# |mean_sunshine_hrs|float|sunshine-duration-monthly-mean-daily-duration|Monthly mean sunshine hours in a day|
# |mean_rh|float|relative-humidity-monthly-mean|Monthly mean relative humidity|
# |year|int|Singapore_climate_data_2022|Years ranging from 1982 - 2022|
# |Month|string|Singapore_climate_data_2022|Month in a year|
# |Seafood Wholesale (Tonnes)|int|SG-seafood-supply|Refers to seafood sold at Singapore's fishery ports and include local landings of seafood and imports of seafood. Includes fresh, frozen seafood and 'Low-value fish'.|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'rainfall-monthly-total': xxx, 'no_of_rainy_days': xxx, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which month have the highest and lowest total rainfall in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest total rainfall in the date range of analysis?
#         - Which month have the highest and lowest number of rainy days in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest number of rainy days in the date range of analysis?
#         - Are there any outliers months in the dataset?
#
#     - **The above 5 questions are compulsory. Feel free to explore other trends based on the datasets that you have choosen for analysis. You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#read csv file, drop NA values and check for missing values
#climate = pd.read_csv('data/Singapore_climate_data_2022.csv')
climate.dropna(inplace=True)
climate.isnull().sum()
# Out:
# month                        0
# mean_temp                    0
# mean_sunshine_hrs            0
# mean_rh                      0
# maximum_rainfall_in_a_day    0
# no_of_rainy_days             0
# total_rainfall               0
# year                         0
# wet_bulb_temperature         0
# dtype: int64

# %%
#dataframe shape
climate.shape
# Out:
# (488, 9)

# %%
#check the datatypes
climate.dtypes
# Out:
# month                         object
# mean_temp                    float64
# mean_sunshine_hrs            float64
# mean_rh                      float64
# maximum_rainfall_in_a_day    float64
# no_of_rainy_days             float64
# total_rainfall               float64
# year                          object
# wet_bulb_temperature         float64
# dtype: object

# %%
#rename columns for better readability
climate.rename(columns={
    'mean_temp': 'mean_air_temp',
    'mean_rh': 'mean_relative_humidity',
    'maximum_rainfall_in_a_day': 'max_rainfall_in_a_day',
    'wet_bulb_temperature': 'mean_wet_bulb_temp'    
}, inplace=True)
climate
# Out:
#     month  mean_air_temp  mean_sunshine_hrs  mean_relative_humidity  \
# 0     Jan           25.9                5.6                    81.2
# 1     Feb           27.1                7.6                    79.5
# 2     Mar           27.2                5.1                    82.3
# 3     Apr           27.0                4.7                    85.9
# 4     May           28.0                5.8                    83.2
# ..    ...            ...                ...                     ...
# 483   Apr           28.1                5.2                    80.0
# 484   May           29.2                6.7                    76.5
# 485   Jun           27.9                4.7                    79.1
# 486   Jul           28.6                6.2                    76.8
# 487   Aug           28.1                5.5                    77.4
#
#      max_rainfall_in_a_day  no_of_rainy_days  total_rainfall  year  \
# 0                     36.5              10.0           107.1  1982
# ...

# %%
sd = {"mean_air_temp": "",
      "mean_sunshine_hrs": "",
      "mean_relative_humidity": "",
      "max_rainfall_in_a_day": "",
      "no_of_rainy_days": "",
      "total_rainfall": "",
      "mean_wet_bulb_temp": ""
}
#for loop to iterate through climate dataframe and append std dev values to sd dictionary
for col in climate.columns:
    if col != 'month' and col != 'year':
        col_values = climate[col].values
        sigma = std_dev(col_values)
        sd[col] = round(sigma, 4)
        
sd
# Out:
# {'mean_air_temp': 0.8014,
#  'mean_sunshine_hrs': 1.2045,
#  'mean_relative_humidity': 3.4104,
#  'max_rainfall_in_a_day': 35.7098,
#  'no_of_rainy_days': 4.9423,
#  'total_rainfall': 113.7993,
#  'mean_wet_bulb_temp': 0.5934}

# %%
#Use of dictionary comprenhension equivalent to  iterate climate dataframe and append std dev values to sd dictionary
sd = {col: round(std_dev(climate[col].values), 4) for col in climate.columns if col != 'month' and col != 'year'}
sd
# Out:
# {'mean_air_temp': 0.8014,
#  'mean_sunshine_hrs': 1.2045,
#  'mean_relative_humidity': 3.4104,
#  'max_rainfall_in_a_day': 35.7098,
#  'no_of_rainy_days': 4.9423,
#  'total_rainfall': 113.7993,
#  'mean_wet_bulb_temp': 0.5934}

# %% [markdown]
# ## *Which month have the highest and lowest total rainfall in 1990, 2000, 2010 and 2020?*

# %%
#Filter to show only first 5 rows of rainfall data variables in 1990, 2000, 2010, 2020
climate['year'] = climate['year'].astype(int)
tot_rain = climate[climate['year'].isin([1990, 2000, 2010, 2020])]
tot_rain.head()
# Out:
#     month  mean_air_temp  mean_sunshine_hrs  mean_relative_humidity  \
# 96    Jan           26.2                5.3                    83.8
# 97    Feb           27.6                8.9                    80.9
# 98    Mar           28.2                8.3                    77.6
# 99    Apr           28.5                6.3                    81.2
# 100   May           28.6                6.5                    81.1
#
#      max_rainfall_in_a_day  no_of_rainy_days  total_rainfall  year  \
# 96                    73.9              13.0           147.4  1990
# 97                     6.6               8.0            24.1  1990
# 98                    48.6               4.0            94.2  1990
# 99                    12.0              10.0            52.4  1990
# 100                  153.7              11.0           180.1  1990
#
#      mean_wet_bulb_temp
# 96            24.047312
# 97            24.961756
# 98            25.079570
# 99            25.885972
# 100           25.933065

# %%
#Generate a list of arguments to pass into subplot function
df = tot_rain
y_param = 'total_rainfall'
title_list = "Rainfall in"
y_lab = "Total Rainfall (mm)"

# %%
#subplot function to generate bar charts for total rainfall in 1990, 2000, 2010, 2020
def sub_bar_plots(df, y_param, title_list, y_lab):
    fig, ax = plt.subplots(2, 2, figsize=(15, 10))
    ax = ax.ravel()
    for i, year in enumerate([1990, 2000, 2010, 2020]):
        data = df[df['year'] == year]
        data.plot(kind='bar', x='month', y=y_param, ax=ax[i])
        ax[i].set_title(f'{title_list} {year}')
        ax[i].set_xlabel('month')
        ax[i].set_ylabel(y_lab)
        ax[i].legend(loc='upper left')
    plt.tight_layout()
    plt.show()

# %%
sub_bar_plots(df, y_param, title_list, y_lab)

# %%
years = [1990, 2000, 2010, 2020]
#Iterate and print out the month with the highest and lowest amount of rainfall in each of the given years
for year in years:
    max_rf = tot_rain[tot_rain['year'] == year].groupby(['year', 'month'])['total_rainfall'].agg(['max']).sort_values(by='max', ascending=False).head(1).reset_index()
    print(f'{max_rf.iloc[0]["month"]} has the highest total rainfall in {year}\n')
    
    min_rf = tot_rain[tot_rain['year'] == year].groupby(['year', 'month'])['total_rainfall'].agg(['min']).sort_values(by='min', ascending=True).head(1).reset_index()
    print(f'{min_rf.iloc[0]["month"]} has the lowest total rainfall in {year}\n')
# Out:
# Sep has the highest total rainfall in 1990
#
# Feb has the lowest total rainfall in 1990
#
# Nov has the highest total rainfall in 2000
#
# Sep has the lowest total rainfall in 2000
#
# Jul has the highest total rainfall in 2010
#
# Feb has the lowest total rainfall in 2010
#
# May has the highest total rainfall in 2020
#
# Feb has the lowest total rainfall in 2020

# %% [markdown]
# ## *Which year have the highest and lowest total rainfall in the date range of analysis?*

# %%
#groupby year, total rainfall and sum then sort by descending order, filter to show only largest value
max_tot_rainfall = climate.groupby('year')[['year', 'total_rainfall']].sum().sort_values(by='total_rainfall', ascending=False).head(1)
print(f'{max_tot_rainfall.index[0]} has the highest total rainfall in the date range of analysis\n')

#groupby year, total rainfall and sum then sort by ascending order, filter to show only smallest value
min_tot_rainfall = climate.groupby('year')[['year', 'total_rainfall']].sum().sort_values(by='total_rainfall', ascending=True).head(1)
print(f'{min_tot_rainfall.index[0]} has the lowest total rainfall in the date range of analysis')
# Out:
# 2007 has the highest total rainfall in the date range of analysis
#
# 1997 has the lowest total rainfall in the date range of analysis

# %% [markdown]
# ## Which month have the highest and lowest number of rainy days in 1990, 2000, 2010 and 2020?

# %%
#Generate a list of arguments to pass into subplot function
y_param = 'no_of_rainy_days'
title_list = "Rainy Days in"
y_lab = "No. of Rainy Days"

# %%
sub_bar_plots(df, y_param, title_list, y_lab)

# %%
years = [1990, 2000, 2010, 2020]
#Iterate and print out the month with the highest and lowest amount of rainfall in each of the given years 
for year in years:
    max_rf = tot_rain[tot_rain['year'] == year].groupby(['year', 'month'])['no_of_rainy_days'].agg(['max']).sort_values(by='max', ascending=False).head(1).reset_index()
    print(f'{max_rf.iloc[0]["month"]} has the highest number of rainy days in {year}\n')
    
    min_rf = tot_rain[tot_rain['year'] == year].groupby(['year', 'month'])['no_of_rainy_days'].agg(['min']).sort_values(by='min', ascending=True).head(1).reset_index()
    print(f'{min_rf.iloc[0]["month"]} has the lowest number of rainy days in {year}\n')
# Out:
# Nov has the highest number of rainy days in 1990
#
# Mar has the lowest number of rainy days in 1990
#
# Nov has the highest number of rainy days in 2000
#
# May has the lowest number of rainy days in 2000
#
# Nov has the highest number of rainy days in 2010
#
# Feb has the lowest number of rainy days in 2010
#
# Jul has the highest number of rainy days in 2020
#
# Jan has the lowest number of rainy days in 2020

# %% [markdown]
# ## *Which year have the highest and lowest number of rainy days in the date range of analysis?*

# %%
#groupby year, number of rainy days and sum then sort by descending order, filter to show only largest value
max_rainy_days = climate.groupby('year')[['year', 'no_of_rainy_days']].sum().sort_values(by='no_of_rainy_days', ascending=False).head(1)
print(f'{max_rainy_days.index[0]} has the highest number rainy days in the date range of analysis\n')

#groupby year, number of rainy days and sum then sort by ascending order, filter to show only smallest value
min_rainy_days = climate.groupby('year')[['year', 'no_of_rainy_days']].sum().sort_values(by='no_of_rainy_days', ascending=True).head(1)
print(f'{min_rainy_days.index[0]} has the lowest number rainy days in the date range of analysis')
# Out:
# 2013 has the highest number rainy days in the date range of analysis
#
# 1997 has the lowest number rainy days in the date range of analysis

# %% [markdown]
# ## *Are there any outliers months in the dataset?*

# %%
#By definition, outliers are defined to be outside the range of +-1.5 IQR from the 25th and 75th quantile
#outlier filter function
def outlier_filter(var):
    Q1, Q3 = climate[var].quantile([0.25, 0.75])
    IQR = Q3 - Q1
    upper_lim = climate[var].quantile(0.75) + 1.5 * IQR
    lower_lim = climate[var].quantile(0.25) - 1.5 * IQR
    outliers = climate[(climate[var] > upper_lim) | (climate[var] < lower_lim)]
    return outliers

# %%
#apply outlier filter function, groupby month and iterate for loop to print outlier months 
#for each rainfall variable in the cleaned dataset
filter1 = outlier_filter('total_rainfall').groupby('month').value_counts().reset_index()[['month', 'total_rainfall']]
cnt1 = 0
for i in filter1['month'].unique():
    print(f'{i} has outlier points for total rainfall variable in the dataset\n')
    cnt1+=1
if cnt1 == 0:
    print(f'No outlier points observed for total rainfall variable in the dataset')
# Out:
# Dec has outlier points for total rainfall variable in the dataset
#
# Feb has outlier points for total rainfall variable in the dataset
#
# Jan has outlier points for total rainfall variable in the dataset
#
# Nov has outlier points for total rainfall variable in the dataset

# %%
filter2 = outlier_filter('max_rainfall_in_a_day').groupby('month').value_counts().reset_index()[['month', 'max_rainfall_in_a_day']]
cnt2 = 0
for i in filter2['month'].unique():
    print(f'{i} has outlier points for the maximum rainfall in a day variable in the dataset\n')
    cnt2+=1
if cnt2 == 0:
    print(f'No outlier points observed for maximum rainfall in a day variable in the dataset')
# Out:
# Aug has outlier points for the maximum rainfall in a day variable in the dataset
#
# Dec has outlier points for the maximum rainfall in a day variable in the dataset
#
# Feb has outlier points for the maximum rainfall in a day variable in the dataset
#
# Jan has outlier points for the maximum rainfall in a day variable in the dataset
#
# Jul has outlier points for the maximum rainfall in a day variable in the dataset
#
# Jun has outlier points for the maximum rainfall in a day variable in the dataset
#
# Mar has outlier points for the maximum rainfall in a day variable in the dataset
#
# May has outlier points for the maximum rainfall in a day variable in the dataset
#
# Nov has outlier points for the maximum rainfall in a day variable in the dataset
#
# Oct has outlier points for the maximum rainfall in a day variable in the dataset
#
# Sep has outlier points for the maximum rainfall in a day variable in the dataset

# %%
cnt3 = 0
filter3 = outlier_filter('no_of_rainy_days').groupby('month').value_counts().reset_index()[['month', 'no_of_rainy_days']]
for i in filter3['month'].unique():
    print(f'{i} has outlier points for the number of rainy days variable in the dataset\n')
    cnt3+=1
if cnt3 == 0:
    print(f'No outlier points observed for number of rainy days variable in the dataset')
# Out:
# No outlier points observed for number of rainy days variable in the dataset

# %%
cnt4 = 0
filter4 = outlier_filter('mean_air_temp').groupby('month').value_counts().reset_index()[['month', 'mean_air_temp']]
for i in filter4['month'].unique():
    print(f'{i} has outlier points for the mean air temperature variable in the dataset\n')
    cnt4+=1
if cnt4 == 0:
    print(f'No outlier points observed for mean air temperature variable in the dataset')
# Out:
# No outlier points observed for mean air temperature variable in the dataset

# %%
cnt5 = 0
filter5 = outlier_filter('mean_sunshine_hrs').groupby('month').value_counts().reset_index()[['month', 'mean_sunshine_hrs']]
for i in filter5['month'].unique():
    print(f'{i} has outlier points for the mean sunshine hours variable in the dataset\n')
    cnt5+=1
if cnt5 == 0:
    print(f'No outlier points observed for mean sunshine hours variable in the dataset')
# Out:
# Feb has outlier points for the mean sunshine hours variable in the dataset

# %%
cnt6 = 0
filter6 = outlier_filter('mean_relative_humidity').groupby('month').value_counts().reset_index()[['month', 'mean_relative_humidity']]
for i in filter6['month'].unique():
    print(f'{i} has outlier points for the mean relative humidity variable in the dataset\n')
    cnt6+=1
if cnt6 == 0:
    print(f'No outlier points observed for mean relative humidity variable in the dataset')
# Out:
# Aug has outlier points for the mean relative humidity variable in the dataset
#
# Dec has outlier points for the mean relative humidity variable in the dataset
#
# Mar has outlier points for the mean relative humidity variable in the dataset
#
# Oct has outlier points for the mean relative humidity variable in the dataset

# %%
cnt7 = 0
filter7 = outlier_filter('mean_wet_bulb_temp').groupby('month').value_counts().reset_index()[['month', 'mean_wet_bulb_temp']]
for i in filter7['month'].unique():
    print(f'{i} has outlier points for the hourly wet bulb variable in the dataset\n')
    cnt7+=1
if cnt7 == 0:
    print(f'No outlier points observed for hourly wet bulb variable in the dataset')
# Out:
# Dec has outlier points for the hourly wet bulb variable in the dataset
#
# Feb has outlier points for the hourly wet bulb variable in the dataset
#
# Jan has outlier points for the hourly wet bulb variable in the dataset
#
# May has outlier points for the hourly wet bulb variable in the dataset

# %% [markdown]
# - 1997 is suggested to be the driest month with the least amount of total rainfall and rainy days according to the analysis
#
# - The period from Feb to Apr and Aug to Oct are observed to have the lowest total rainfall which generally coincides with the end of the respective moonsoon seasons.
#
# - The period from Feb to Apr is observed to have the lowest number of rainy days.
#
# - The period from Nov to Jan is observed to have the highest total rainfall and number rainy days which generally coincides with the start of the year end monsoon season

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# Some ideas for plots that can be generated:
#
# - Plot the histogram of the rainfall data with various bins and comment on the distribution of the data - is it centered, skewed?
# - Plot the box-and-whiskers plot. Comment on the different quartiles and identify any outliers in the dataset.
# - Is there a correlation between the number of rainy days and total rainfall in the month? What kind of correlation do your suspect? Does the graph show the same?

# %% [markdown]
# # 1. Temporal trends:

# %%
#show first 5 rows of cleaned data
climate.head()
# Out:
#   month  mean_air_temp  mean_sunshine_hrs  mean_relative_humidity  \
# 0   Jan           25.9                5.6                    81.2
# 1   Feb           27.1                7.6                    79.5
# 2   Mar           27.2                5.1                    82.3
# 3   Apr           27.0                4.7                    85.9
# 4   May           28.0                5.8                    83.2
#
#    max_rainfall_in_a_day  no_of_rainy_days  total_rainfall  year  \
# 0                   36.5              10.0           107.1  1982
# 1                    9.4               5.0            27.8  1982
# 2                   61.7              11.0           160.8  1982
# 3                   45.1              14.0           157.0  1982
# 4                   33.0              10.0           102.2  1982
#
#    mean_wet_bulb_temp
# 0           23.456048
# 1           24.297619
# 2           24.811559
# 3           25.103750
# 4           25.689651

# %%
#generate correlation table of all variables
climate.corr()
# Out:
#                         mean_air_temp  mean_sunshine_hrs  \
# mean_air_temp                1.000000           0.491729
# mean_sunshine_hrs            0.491729           1.000000
# mean_relative_humidity      -0.631752          -0.594081
# max_rainfall_in_a_day       -0.400713          -0.387892
# no_of_rainy_days            -0.362360          -0.679018
# total_rainfall              -0.514120          -0.575614
# year                         0.327637           0.122733
# mean_wet_bulb_temp           0.775680           0.146242
#
#                         mean_relative_humidity  max_rainfall_in_a_day  \
# mean_air_temp                        -0.631752              -0.400713
# mean_sunshine_hrs                    -0.594081              -0.387892
# mean_relative_humidity                1.000000               0.438402
# max_rainfall_in_a_day                 0.438402               1.000000
# no_of_rainy_days                      0.582346               0.396088
# ...

# %%
#plot heatmap to show the correlation between variables
plt.figure(figsize=(15, 15))
df = climate.corr()
sns.heatmap(df.corr(), annot=True, cmap='coolwarm');
plt.title('Heat Map of Numerical Columns in Dataframe',size=20, fontweight="bold")
plt.show()

# %% [markdown]
# ## Is there a relationship between the total rainfall received and other variables?

# %%
 #create list of units
units = ['days', 'mm', '%', 'hrs', '°C', '°C']
#Initialise 3x2 subplot grid
fig, ax = plt.subplots(3, 2, figsize=(15, 10)) 
#for loop to iterate given list of possbile features, plot the respective scatter plots
for i, x in enumerate(['no_of_rainy_days', 'max_rainfall_in_a_day', 'mean_relative_humidity',
                       'mean_sunshine_hrs', 'mean_air_temp', 'mean_wet_bulb_temp']):
    row = i // 2
    col = i % 2
    sns.regplot(x=x, y='total_rainfall', data=climate, ax=ax[row][col], line_kws={'color': 'red'})
    ax[row][col].set_title(f'Scatter plot of {x} vs total rainfall')
    ax[row][col].set_ylabel('Total rainfall (mm)')
    ax[row][col].set_xlabel(f'{x} ({units[i]})')

plt.tight_layout()
plt.show()

# %% [markdown]
# - We observed that having a higher amount of rainy days per month and higher maximum rainfall in a day per month results in a greater amount of total rainfall
#
# - Having a higher average relative humidity also indicates a greater amount of total overall rainfall as it increases the likelihood for cloud formation through condensation
#
# - Having a higher average air temperature and sunshine hours indicates a smaller amount of total overall rainfall due to greater cloud cover in the atmosphere which lowers the amount of sunlight received
#
# - No possible correlation is observed between total rainfall and average wet bulb temperature

# %% [markdown]
# ## Is there a relationship between the relative humidity and other variables?

# %%
#Initialise 3x2 subplot grid
fig, ax = plt.subplots(3, 2, figsize=(15, 10))
#for loop to iterate given list of possbile features, plot the respective scatter plots
for i, x in enumerate(['no_of_rainy_days', 'max_rainfall_in_a_day', 'total_rainfall',
                       'mean_sunshine_hrs', 'mean_air_temp', 'mean_wet_bulb_temp']):
    row = i // 2
    col = i % 2
    sns.regplot(x='mean_relative_humidity', y=x, data=climate, ax=ax[row][col], line_kws={'color': 'red'})
    ax[row][col].set_title(f'Scatter plot of {x} vs mean_relative_humidity')
    ax[row][col].set_ylabel(f'{x} ({units[i]})')
    ax[row][col].set_xlabel('Mean Relative Humidity (%)')

plt.tight_layout()
plt.show()

# %% [markdown]
# - We observed that having a higher average relative humidity results in a higher amount of rainy days per month, amount of total overall rainfall and maximum rainfall in a day. This suggests that the likelihood of precipitation is higher due to greater amount of water vapor per volume in the air for cloud formation to take place through condendation
#
# - Having a higher average relative humidity indicates a lower overall average sunshine hours and air temperature due to greater cloud cover in the atmosphere which lowers the evaporation rate of water vapor formation in the atmosphere
#
# - No possible correlation is observed between average relative humidity and average wet bulb temperature

# %% [markdown]
# ## Are there any patterns or trends in the mean temperature, mean sunshine hours over the 20-year period (1982-2022)?

# %%
#groupby climate dataframe with year
ann_mean = climate.groupby('year').mean().reset_index()
ann_mean.head()
# Out:
#    year  mean_air_temp  mean_sunshine_hrs  mean_relative_humidity  \
# 0  1982      27.358333           5.750000               81.966667
# 1  1983      27.666667           5.625000               82.283333
# 2  1984      26.766667           5.083333               84.616667
# 3  1985      27.116667           5.591667               83.208333
# 4  1986      27.100000           5.525000               82.866667
#
#    max_rainfall_in_a_day  no_of_rainy_days  total_rainfall  mean_wet_bulb_temp
# 0              38.150000         10.833333      131.808333           24.921417
# 1              57.891667         12.083333      166.141667           25.234144
# 2              66.758333         15.916667      223.891667           24.721475
# 3              32.016667         15.083333      123.658333           24.857212
# 4              59.933333         14.500000      211.341667           24.802940

# %%
#create a list of features and units
ann_df = ann_mean
title_list = ['Annuual mean Air Temperature from 1982-2022', 'Annual mean Sunshine Temperature from 1982-2022', 
              'Annuual mean Relative Humidity from 1982-2022']

units = ['°C', 'hrs', '%']

# %%
#Initialise 3x1 subgrid
fig, ax = plt.subplots(3, 1, figsize=(15, 10))
#for loop to iterate given list of possbile features, plot the respective line plots
for i, param in enumerate(['mean_air_temp', 'mean_sunshine_hrs', 'mean_relative_humidity']):
    row = i // 2
    col = i % 2
    sns.lineplot(data=ann_df, x='year', y=param, ax=ax[i])
    ax[i].set_title(title_list[i])
    ax[i].set_xlabel('Year')
    ax[i].set_ylabel(f'{param} ({units[i]})')
    ax[i].set_xlim(1982, 2022)
    ax[i].set_xticks(ann_df['year'])
    ax[i].set_xticklabels(labels=ann_df['year'], rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# - The average annual air temperature has been steadily increasing after 1990
#
# - The average annual sunshine temperature, relative humidity has been steadily increasing and decreasing respectively after 2013
#
# - Exception years that do not follow these trends include 2017 and 2019. 2017 recorded significantly higher annual mean relative humidity which corresponds to greater overall number of rainy days throughout the year(observed in next cell).
#
# - 2019 recorded significantly higher annual mean sunshine which corresponds to smaller amount of rainy days and lower total rainfall throughout the year(observed in next cell).

# %% [markdown]
# # 2. Rain patterns:

# %% [markdown]
# ## How does the number of rainy days, maximum rainfall in a day, total number of rainfall vary of the  years?

# %%
title_list1 = ['No. of Rainy days from 1982-2022', 'Maximum Rainfall in a day from 1982-2022', 
              'Total Rainfall from 1982-2022']
units1 = ['year', 'mm', 'mm']
#Initialise 3x1 subgrid
fig, ax = plt.subplots(3, 1, figsize=(15, 10))
#for loop to iterate given list of possbile features, plot the respective line plots
for i, param in enumerate(['no_of_rainy_days', 'max_rainfall_in_a_day', 'total_rainfall']):
    row = i // 2
    col = i % 2
    sns.lineplot(data=ann_df, x='year', y=param, ax=ax[i])
    ax[i].set_title(title_list1[i])
    ax[i].set_xlabel('Year')
    ax[i].set_ylabel(f'{param} ({units1[i]})')
    ax[i].set_xlim(1982, 2022)
    ax[i].set_xticks(ann_df['year'])
    ax[i].set_xticklabels(labels=ann_df['year'], rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# - Peak data points indicating high rain activity are relatively consistent across all 3 rainfall variables over the last 20 years
#
# - Average annual total rainfall and maximum rainfall in a day is decreasing from 2015 onwards
#
# - All 3 rainfall parameters are observed to be the lowest in 1997 and 2015, and it can suggest that these are either the driest(low humidity) or hottest(high air temperaure) years throughout the last 20 years. However, only 2015 depicts a significantly higher average air temperature, sunshine hours and lower average relative humidity but not 1997.
#
# - This observations might suggest that climate change has became significant in context of Singapore starting from 2015

# %% [markdown]
# ### *Are there any outliers months in the dataset with respect to Total Rainfall, Maximum Rainfall in a Day and Number of Rainy Days?*

# %%
#plot the histogram with custom axis labels
a = sns.displot(climate['total_rainfall'], bins=10, kde=True)
a.set_axis_labels(x_var='Total Rainfall (mm)')

# Get the mean and standard deviation
mean1 = round(climate['total_rainfall'].mean(), 2)
std1 = round(climate['total_rainfall'].std(), 2)

# Add mean and standard deviation lines
plt.axvline(mean1, color='red', linestyle='--')
plt.axvline(mean1 + std1, color='green', linestyle='--')
plt.axvline(mean1 - std1, color='green', linestyle='--')

#plot the histogram with custom axis labels
b = sns.displot(climate['max_rainfall_in_a_day'], bins=20, kde=True)
b.set_axis_labels(x_var='Maximum rainfall in a day (mm)')

# Get the mean and standard deviation
mean2 = round(climate['max_rainfall_in_a_day'].mean(), 2)
std2 = round(climate['max_rainfall_in_a_day'].std(), 2)

# Add mean and standard deviation lines
plt.axvline(mean2, color='red', linestyle='--')
plt.axvline(mean2 + std2, color='green', linestyle='--')
plt.axvline(mean2 - std2, color='green', linestyle='--')

#plot the histogram with custom axis labels
c = sns.displot(climate['no_of_rainy_days'], bins=13, kde=True)
c.set_axis_labels(x_var='No. of Rainy Days')

# Get the mean and standard deviation
mean3 = round(climate['no_of_rainy_days'].mean(), 2)
std3 = round(climate['no_of_rainy_days'].std(), 2)

# Add mean and standard deviation lines
plt.axvline(mean3, color='red', linestyle='--')
plt.axvline(mean3 + std3, color='green', linestyle='--')
plt.axvline(mean3 - std3, color='green', linestyle='--');

print(f'Mean Total Rainfall: {mean1} (mm)')
print(f'Standard Deviation Total Rainfall: {std1}')
print(f'Mean maximum rainfall in a day: {mean2} (mm)')
print(f'Standard Deviation of maximum rainfall in a day: {std2}')
print(f'Mean number of rainy days: {mean3}')
print(f'Standard Deviation of number of rainy days: {std3}')
# Out:
# Mean Total Rainfall: 177.16 (mm)
# Standard Deviation Total Rainfall: 113.92
# Mean maximum rainfall in a day: 52.33 (mm)
# Standard Deviation of maximum rainfall in a day: 35.75
# Mean number of rainy days: 14.06
# Standard Deviation of number of rainy days: 4.95

# %% [markdown]
# - Total rainfall data is skewed to the left, there are possible outlier data points with high total rainfall
#
# - Maxmium rainfall in a day dataset is skewed to the left, there are possible outlier data points with abnormally high maximum rainfall in a day
#
# - Number of rainy days variable is centered following a normal distribution

# %% [markdown]
# ### *Are there any outliers months in the dataset with respect to Mean Air Temperature, Mean Sunshine Hours and Mean Relative Humidity?*

# %%
#plot the histogram with custom axis labels
a = sns.displot(climate['mean_air_temp'], bins=11, kde=True)
a.set_axis_labels(x_var='Mean Air Temperature (°C)')

# Get the mean and standard deviation
mean4 = round(climate['mean_air_temp'].mean(), 2)
std4 = round(climate['mean_air_temp'].std(), 2)

# Add mean and standard deviation lines
plt.axvline(mean4, color='red', linestyle='--')
plt.axvline(mean4 + std4, color='green', linestyle='--')
plt.axvline(mean4 - std4, color='green', linestyle='--')

#plot the histogram with custom axis labels
b = sns.displot(climate['mean_sunshine_hrs'], bins=21, kde=True)
b.set_axis_labels(x_var='Mean Sunshine Hours (hrs)')

# Get the mean and standard deviation
mean5 = round(climate['mean_sunshine_hrs'].mean(), 2)
std5 = round(climate['mean_sunshine_hrs'].std(), 2)

# Add mean and standard deviation lines
plt.axvline(mean5, color='red', linestyle='--')
plt.axvline(mean5 + std5, color='green', linestyle='--')
plt.axvline(mean5 - std5, color='green', linestyle='--')

#plot the histogram with custom axis labels
c = sns.displot(climate['mean_relative_humidity'], bins=13, kde=True)
c.set_axis_labels(x_var='Mean Relative Humidity (%)')

# Get the mean and standard deviation
mean6 = round(climate['mean_relative_humidity'].mean(), 2)
std6 = round(climate['mean_relative_humidity'].std(), 2)

# Add mean and standard deviation lines
plt.axvline(mean6, color='red', linestyle='--')
plt.axvline(mean6 + std6, color='green', linestyle='--')
plt.axvline(mean6 - std6, color='green', linestyle='--');

print(f'Mean Air Temperature: {mean4} (°C)')
print(f'Standard Deviation of mean air temperature: {std4}')
print(f'Mean Sunshine Hours: {mean5} (hrs)')
print(f'Standard Deviation of mean sunshine hours: {std5}')
print(f'Mean Relative Humidity: {mean6} (%)')
print(f'Standard Deviation of mean relative humidity: {std6}')
# Out:
# Mean Air Temperature: 27.68 (°C)
# Standard Deviation of mean air temperature: 0.8
# Mean Sunshine Hours: 5.69 (hrs)
# Standard Deviation of mean sunshine hours: 1.21
# Mean Relative Humidity: 82.25 (%)
# Standard Deviation of mean relative humidity: 3.41

# %% [markdown]
# - All 3 rainfall related parameters on Mean Air Temperature, Mean Sunshine Hours, and Mean Relative Humidity follow a normal distribution relatively. This suggests that there are no significant outlier data points in these parameters.

# %% [markdown]
# ### *BoxPlots of various related rainfall parameters across the year in last 20 years*

# %%
#initialise 3x1 grid and plot the boxplots
fig, ax = plt.subplots(3, 1, figsize=(16, 12))

g = sns.boxplot(data=climate, x=climate['month'], y=climate['total_rainfall'], ax=ax[0]).set(title='Box plot for Total Rainfall (mm)')
ax[0].set(xlabel="month", ylabel="Total Rainfall (mm)");

h = sns.boxplot(data=climate, x=climate['month'], y=climate['max_rainfall_in_a_day'], ax=ax[1]).set(title='Box plot for Maximum rainfall in a day (mm')
ax[1].set(xlabel="month", ylabel="Maximum rainfall in a day (mm)")

j = sns.boxplot(data=climate, x=climate['month'], y=climate['no_of_rainy_days'], ax=ax[2]).set(title='Box plot for No. of Rainy Days')
ax[2].set(xlabel="month", ylabel="No. of Rainy Days");

plt.subplots_adjust(hspace=0.5)
plt.show()

# %% [markdown]
# - Months of Jan, Feb, May, Jul, Sept and Dec have outlier points in the total rainfall variable
#
# - Significant number of outlier points are observed across the year with high amounts of maximum rainfall in a day
#
# - Little to no outlier points are observed across the year in the No. of Rainy Days variable
#
# - Months of Nov, Dec and Jan have higher overall average total rainfall and maximum number of rainfall in a day.
#
# - Months of Nov and Dec have a higher overall average number of rainy days

# %%
#initialise 3x1 grid and plot the boxplots
fig, ax = plt.subplots(3, 1, figsize=(16, 12))

k = sns.boxplot(data=climate, x=climate['month'], y=climate['mean_air_temp'], ax=ax[0]).set(title='Box plot for Mean Air Temperature (°C)')
ax[0].set(xlabel="month", ylabel="Mean Air Temperature (°C)");

m = sns.boxplot(data=climate, x=climate['month'], y=climate['mean_sunshine_hrs'], ax=ax[1]).set(title='Box plot for Mean Sunshine Hours (hrs)')
ax[1].set(xlabel="month", ylabel="Maximum rainfall in a day (mm)")

n = sns.boxplot(data=climate, x=climate['month'], y=climate['mean_relative_humidity'], ax=ax[2]).set(title='Box plot for Mean Relative Humidity (°C)')
ax[2].set(xlabel="month", ylabel="Mean Relative Humidity (°C)");

plt.subplots_adjust(hspace=0.5)
plt.show()

# %% [markdown]
# - November, December, January have a lower mean air temperature, higher mean relative humidity which coincides with the year-end(northeast) monsoon season
#
# - November, December have a lower amount of mean sunshine hours which is similar to having a higher number of rainy days in a month.

# %% [markdown]
# # 4. Further Analysis of Rainfall variables to  the Business Problem (Optional)

# %% [markdown]
# ## Is there a relationship between Singapore's Seafood supply and selected rainfall variables?

# %% [markdown]
# ### *Data cleaning of external source dataset*

# %%
#read csv file and print first 20 rows
seafood = pd.read_csv('../data/SG-seafood-supply.csv')
seafood.head(20)
# Out:
#                                            Unnamed: 0  \
# 0                                     Theme: Industry
# 1   Subject: Agriculture, Animal Production and Fi...
# 2                                  Topic: Food Supply
# 3   Table Title: Seafood Supply And Wholesale, Mon...
# 4                                                 NaN
# 5                       Data last updated: 30/12/2022
# 6   Source: AGRI-FOOD AND VETERINARY AUTHORITY, SI...
# 7                                                 NaN
# 8                                         Data Series
# 9                                            2022 Nov
# 10                                           2022 Oct
# 11                                           2022 Sep
# 12                                           2022 Aug
# 13                                           2022 Jul
# 14                                           2022 Jun
# 15                                           2022 May
# ...

# %%
#print last 30 rows
seafood.tail(30)
# Out:
#                                             Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 291                                           1999 May         na       7793
# 292                                           1999 Apr         na       7375
# 293                                           1999 Mar         na       9544
# 294                                           1999 Feb         na       7546
# 295                                           1999 Jan         na       8477
# 296                                                NaN        NaN        NaN
# 297                                         Footnotes:        NaN        NaN
# 298  Seafood refers to fish, crustaceans and molluscs.        NaN        NaN
# 299                Local Landings Of Seafood (Tonnes):        NaN        NaN
# 300  Refers to seafood catch from local waters.  Pr...        NaN        NaN
# 301                       Imports Of Seafood (Tonnes):        NaN        NaN
# ...

# %%
#rename the headers to the appropriate namings based on information from row index 8
seafood.rename(columns={
    'Unnamed: 0': 'Data Series',
    'Unnamed: 1': 'Local Landings Of Seafood (Tonnes)',
    'Unnamed: 2': 'Imports Of Seafood (Tonnes)',
    'Unnamed: 3': 'Exports Of Seafood (Tonnes)',
    'Unnamed: 4': 'Seafood Wholesale (Tonnes)'
}, inplace=True)
seafood
# Out:
#                                            Data Series  \
# 0                                      Theme: Industry
# 1    Subject: Agriculture, Animal Production and Fi...
# 2                                   Topic: Food Supply
# 3    Table Title: Seafood Supply And Wholesale, Mon...
# 4                                                  NaN
# ..                                                 ...
# 316  Values are shown in Singapore dollars (unless ...
# 317                                                NaN
# 318               Generated by: SingStat Table Builder
# 319                         Date generated: 15/02/2023
# 320                      Contact: info@singstat.gov.sg
#
#     Local Landings Of Seafood (Tonnes) Imports Of Seafood (Tonnes)  \
# 0                                  NaN                         NaN
# 1                                  NaN                         NaN
# 2                                  NaN                         NaN
# ...

# %%
#filter away row indices which are redundant to the dataset
seafood = seafood.iloc[9:-25,:].reset_index()
seafood.drop(columns='index', inplace=True)

# %%
#column info
seafood.columns
# Out:
# Index(['Data Series', 'Local Landings Of Seafood (Tonnes)',
#        'Imports Of Seafood (Tonnes)', 'Exports Of Seafood (Tonnes)',
#        'Seafood Wholesale (Tonnes)'],
#       dtype='object')

# %%
#replace 'na' string with null values
seafood.replace('na', np.NaN, inplace=True)
seafood.isnull().sum()
# Out:
# Data Series                            0
# Local Landings Of Seafood (Tonnes)    36
# Imports Of Seafood (Tonnes)            6
# Exports Of Seafood (Tonnes)            6
# Seafood Wholesale (Tonnes)            96
# dtype: int64

# %%
#check data types
seafood.dtypes
# Out:
# Data Series                           object
# Local Landings Of Seafood (Tonnes)    object
# Imports Of Seafood (Tonnes)           object
# Exports Of Seafood (Tonnes)           object
# Seafood Wholesale (Tonnes)            object
# dtype: object

# %%
# Convert the column to numeric using pd.to_numeric with errors='coerce'
columns = ['Local Landings Of Seafood (Tonnes)', 'Imports Of Seafood (Tonnes)', 
           'Exports Of Seafood (Tonnes)', 'Seafood Wholesale (Tonnes)']

for column in columns:
    seafood[column] = pd.to_numeric(seafood[column], errors='coerce')

# The resulting DataFrame will have the numeric values and the non-numeric values will be converted to NaN
seafood
# Out:
#     Data Series  Local Landings Of Seafood (Tonnes)  \
# 0      2022 Nov                                13.0
# 1      2022 Oct                                14.0
# 2      2022 Sep                                16.0
# 3      2022 Aug                                17.0
# 4      2022 Jul                                15.0
# ..          ...                                 ...
# 282    1999 May                                 NaN
# 283    1999 Apr                                 NaN
# 284    1999 Mar                                 NaN
# 285    1999 Feb                                 NaN
# 286    1999 Jan                                 NaN
#
#      Imports Of Seafood (Tonnes)  Exports Of Seafood (Tonnes)  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# ...

# %%
#check datatypes after conversion
seafood.dtypes
# Out:
# Data Series                            object
# Local Landings Of Seafood (Tonnes)    float64
# Imports Of Seafood (Tonnes)           float64
# Exports Of Seafood (Tonnes)           float64
# Seafood Wholesale (Tonnes)            float64
# dtype: object

# %%
#check for null values
seafood.isnull().sum()
# Out:
# Data Series                            0
# Local Landings Of Seafood (Tonnes)    36
# Imports Of Seafood (Tonnes)            6
# Exports Of Seafood (Tonnes)            6
# Seafood Wholesale (Tonnes)            96
# dtype: int64

# %%
#drop NA values, print first 5 rows
seafood.dropna(inplace=True)
seafood.head()
# Out:
#    Data Series  Local Landings Of Seafood (Tonnes)  \
# 6     2022 May                                17.0
# 7     2022 Apr                                16.0
# 8     2022 Mar                                18.0
# 9     2022 Feb                                21.0
# 10    2022 Jan                                32.0
#
#     Imports Of Seafood (Tonnes)  Exports Of Seafood (Tonnes)  \
# 6                        9382.0                       1030.0
# 7                       10469.0                       1162.0
# 8                        9538.0                       1061.0
# 9                        7515.0                       1423.0
# 10                      10749.0                       1200.0
#
#     Seafood Wholesale (Tonnes)
# 6                       2319.0
# 7                       2897.0
# 8                       2910.0
# 9                       2241.0
# 10                      3390.0

# %%
#strip off first 2 spaces in 'Data Series' column, and .str.split into year and month
seafood['Data Series'] = seafood[['Data Series']].apply(lambda x: x.str.lstrip())
seafood[['year', 'month']] = seafood['Data Series'].str.split(' ', expand=True)
seafood.drop(columns=['Data Series'], inplace=True)

# %%
#check datatypes
seafood.dtypes
# Out:
# Local Landings Of Seafood (Tonnes)    float64
# Imports Of Seafood (Tonnes)           float64
# Exports Of Seafood (Tonnes)           float64
# Seafood Wholesale (Tonnes)            float64
# year                                   object
# month                                  object
# dtype: object

# %%
#typecast year column to float and merge with climate dataset
seafood['year'] = seafood['year'].astype(float)
seafood1 = seafood.merge(climate, on=['year', 'month'], how='left')
seafood1.head()
# Out:
#    Local Landings Of Seafood (Tonnes)  Imports Of Seafood (Tonnes)  \
# 0                                17.0                       9382.0
# 1                                16.0                      10469.0
# 2                                18.0                       9538.0
# 3                                21.0                       7515.0
# 4                                32.0                      10749.0
#
#    Exports Of Seafood (Tonnes)  Seafood Wholesale (Tonnes)    year month  \
# 0                       1030.0                      2319.0  2022.0   May
# 1                       1162.0                      2897.0  2022.0   Apr
# 2                       1061.0                      2910.0  2022.0   Mar
# 3                       1423.0                      2241.0  2022.0   Feb
# 4                       1200.0                      3390.0  2022.0   Jan
#
#    mean_air_temp  mean_sunshine_hrs  mean_relative_humidity  \
# ...

# %%
#check datatypes after merging
seafood1.dtypes
# Out:
# Local Landings Of Seafood (Tonnes)    float64
# Imports Of Seafood (Tonnes)           float64
# Exports Of Seafood (Tonnes)           float64
# Seafood Wholesale (Tonnes)            float64
# year                                  float64
# month                                  object
# mean_air_temp                         float64
# mean_sunshine_hrs                     float64
# mean_relative_humidity                float64
# max_rainfall_in_a_day                 float64
# no_of_rainy_days                      float64
# total_rainfall                        float64
# mean_wet_bulb_temp                    float64
# dtype: object

# %%
#plot updated heatmap to show the correlation between variables
plt.figure(figsize=(15, 15))
sns.heatmap(seafood1.corr(), annot=True, cmap='coolwarm');
plt.title('Heat Map of Numerical Columns in updated Dataframe',size=20, fontweight="bold")
plt.show()

# %% [markdown]
# ### *Scatter plot to illustrate relationship between variables from external dataset and rainfall datasets*

# %%
fig, ax = plt.subplots(2, 2, figsize=(15, 10))
ax = ax.flatten()
units2 = ['days', '%', 'hrs', '°C']
for i, x in enumerate(['no_of_rainy_days', 'mean_relative_humidity',
                       'mean_sunshine_hrs', 'mean_air_temp']):
    
    
    sns.regplot(x=x, y='Seafood Wholesale (Tonnes)', data=seafood1, ax=ax[i], line_kws={'color': 'red'})
    ax[i].set_title(f'Scatter plot of {x} vs Total Seafood Wholesale')
    ax[i].set_xlabel(f'{x} ({units2[i]})')
    ax[i].set_ylabel('Seafood Wholesale (Tonnes)')

plt.tight_layout()
plt.show()

# %% [markdown]
# - We observed that a higher mean relative humidity translates to having more seafood being sold at Singapore Fishery ports. From this observation, it can be hypothesized that certain groups of seafood in the local market are able populate under higher relative humidity conditions.
#
# - No clear relationship can be seen on variables such as number of rainy days, mean sunshine hours and mean air temperature
#
# - Phytoplankton, being the base of the marine food chain, is able to thrive under favorable ocean environment conditions such as high humidity(Enhanced phytoplankton bloom triggered by atmospheric high-pressure systems over the Northern Arabian Sea, Nature 2023). Furthermore, they also serve as either a direct and indirect food source to many marine organisms living in the ocean. These scientific concepts suggest that the relative humidity in the environment could influence the population of marine organisms in the ocean, which can translate to more seafood catches for fisheries.

# %%
fig, ax = plt.subplots(2, 1, figsize=(15, 10))
sns.lineplot(data=seafood1, x='year', y='Seafood Wholesale (Tonnes)', ax=ax[0])
ax[0].set_title('Annual Seafood wholesale 2007-2022')
ax[0].set_ylabel('Seafood Wholesale (Tonnes)')

sns.lineplot(data=seafood1, x='year', y='mean_relative_humidity', ax=ax[1])
ax[1].set_title('Mean Relative Humidity 2007-2022')
ax[1].set_ylabel('Mean Relative Humidity (%)');

# %% [markdown]
# - The overall annual average seafood wholesale sold at fishery ports has been steadily decreasing throughout the time period of 2007 to 2022. Based on this trend and comparing to the annual relative mean humidity data in the 2nd chart, we can infer that there is a relationship between these 2 variables.

# %%
fig, ax = plt.subplots(2, 2, figsize=(15, 10))
ax = ax.flatten()
for i, y in enumerate(['Local Landings Of Seafood (Tonnes)', 'Imports Of Seafood (Tonnes)',
                       'Exports Of Seafood (Tonnes)', 'Seafood Wholesale (Tonnes)']):
    
    
    sns.regplot(x='mean_relative_humidity', y=y, data=seafood1, ax=ax[i], line_kws={'color': 'red'})
    ax[i].set_title(f'Scatter plot of {y} vs Mean Relative Humidity')
    ax[i].set_ylabel(f'{y} (Tonnes)')
    ax[i].set_xlabel('Mean Relative Humidity (%)')

plt.tight_layout()
plt.show()

# %% [markdown]
# - Similar observations can be seen for the other seafood supply metrics based on Singapore context with respect to the mean relative humidity

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# *Conclusion
#
# We have analysed how the performance of the different weather variables vary over the last 20 years according to the Singapore's tropical climate. The amount of rainfall received and number of rainy days are relatively influenced by common weather metrics such as air temperature, relative humidity and sunshine hours. While referencing to our EDA findings, we have also discovered that the relative humidity in Singapore seems to be the key variable in influencing other weather variables as supported scientific theories behind the different stages of the hydrologic cycle, beginning from evaporation and ending at precipitation. However, the likelihood of whether rainfall will occur in any given day will still highly co-depend on the other weather variables.
#
# In the explansion towards the business problem that we have defined earlier in our problem statement, we have also observed that the overall supply and trade of local seafood can be affected by the relative humidity in the environment. With the support of some additional research online, we have found out that the relative humidity could influence the conditions for planktons, the marine organism at the bottom of the marine food chain, to thrive in marine ecosystems.
#
# According to research articles and websites online, it has been extensively studied that planktons are the key components in regulating and keeping the carbon cycle in check which controls the amount of CO2 stored in the oceans. With disruptions to its population as a result of climate change and global warming, it can possibly result in an excessive build up of CO2 in the oceans and threaten the marine ecosystem. Therefore, it is essential to understand how the different weather conditions can affect the overall state of the marine ecosystem and its current role towards climate change.
#
# *Recommendations
#
# The findings from this analysis can help business owners and organisations in the Fishery, F&B and aquaculture sectors to make more informed decisions and optimise their resources more effectively
#
# From this study, we can possibly expand the research towards other environment or weather variables in order to further verify our hypothesis on how the relative humidity can influence the seafood and supply and wholesale trade in Singapore to ensure future sustainability on the production and demand for seafood in Singapore. Some of these examples include:
#
# 1. Quantify how other weather variables such as atmospheric pressure, wind speed and cloud cover to further verify if there is any relationship with respect to the overall seafood supply.
#
# 2. Incorporating pollutant metrics that are strongly associated with climate change such the emission of common greenhouse gasses(Carbon dioxide, Methane) to see how they can affect seafood catches in wild fisheries and harvests from local fish farms
#
# 3. Quantify the relationship between the sales of different seafood sub-types, and also analyse how the different prices of various seafoods can vary with respect to weather parameters.

# %% [markdown]
# ### Sources

# %% [markdown]
# 1. IPCC Sixth Assessment Report 2022: Chapter 10: Asia. In Climate Change 2022: Impacts, Adaptation and Vulnerability
#
# 2. A sustainable food system for Singapore and beyond, SFA Singapore, 11 Nov 2022:
# https://www.sfa.gov.sg/food-for-thought/article/detail/a-sustainable-food-system-for-singapore-and-beyond
#
# 3. IN FOCUS: How climate change can threaten food production in Singapore, CNA Singapore, 19 Dec 2020:
# https://www.channelnewsasia.com/singapore/climate-change-singapore-food-production-fish-eggs-1340266
#
# 4. Enhanced phytoplankton bloom triggered by atmospheric high-pressure systems over the Northern Arabian Sea, Prasad G.Thoppil, 14 Jan 2023: https://www.nature.com/articles/s41598-023-27785-z
#
# 5. Climate change effects on aquaculture production, Global Seafood Alliance, 20 Sept 2021: https://www.globalseafood.org/advocate/climate-change-effects-on-aquaculture-production/
#
# 6. Climate of Singapore: http://www.weather.gov.sg/climate-climate-of-singapore/
#
# 7. National Geographic: Hydrologic Cycle: https://education.nationalgeographic.org/resource/hydrologic-cycle
#
# 8. What are Phytoplankton? NASA Earth Observatory: https://earthobservatory.nasa.gov/features/Phytoplankton
#
# 9. Singapore food statistics 2021: https://www.sfa.gov.sg/docs/default-source/publication/sg-food-statistics/singapore-food-statistics-2021.pdf
